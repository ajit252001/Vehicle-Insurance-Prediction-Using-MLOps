# %%
# !pip install pandas pymongo
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
# ...
#   Using cached dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ------------ --------------------------- 3.4/11.3 MB 16.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.3/11.3 MB 15.5 MB/s eta 0:00:01
#    -------------------------------- ------- 9.2/11.3 MB 14.6 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.3 MB 13.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 12.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/804.8 kB ? eta -:--:--
#    ---------------------------------------- 804.8/804.8 kB 7.0 MB/s  0:00:00
# Using cached dnspython-2.8.0-py3-none-any.whl (331 kB)
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/12.9 MB 7.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.6/12.9 MB 6.9 MB/s eta 0:00:02
# ...
